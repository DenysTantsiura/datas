# %% [markdown]
# В якості домашнього завдання вам пропонується створити нейронну мережу за допомогою механізмів Keras, яка буде __класифікувати__ товари із датасету `fasion_mnist`.
#
# Вам належить запропонувати свою власну архітектуру мережі. Точність найнаївнішої, але адекватної нейромережі становить приблизно __91%__. Точність вашої моделі повинна бути `не нижчою` за цей показник. Щоб досягти таких значень вам знадобиться `поекспериментувати з гіперпараметрами мережі`:
#
# - кількість шарів;
#
# - кількість нейронів;
#
# - функції активації;
#
# - кількість епох;
#
# - розмір батчу;
#
# - вибір оптимізатора;
#
# - різні техніки регуляризації і т.д.
#
# Використайте вивчені `техніки виявлення проблем навчання` нейронної мережі, і потім `поекспериментуйте`.
#
# Рішення оформіть у вигляді окремого ноутбука.

# %%
from typing import Optional, Union

import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.activations import mish, relu, sigmoid, softmax
from tensorflow.keras.datasets import fashion_mnist
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Dense
from keras import losses
from keras import metrics
from keras import optimizers

# import numpy as np
# import matplotlib.pyplot as plt
# from sklearn.metrics import accuracy_score
# import tensorflow as tf
# from tensorflow.keras.activations import sigmoid
# from tensorflow.keras.datasets import mnist
# from tensorflow.keras.metrics import Accuracy
# from tensorflow.keras.utils import to_categorical

# %% [markdown]
# ###### __Dataset__

# %%
# num_classes = 10  # общее количество классов, от 0 до 9
# num_features = 784  # количество атрибутов входного вектора 28 * 28 = 784

learning_rate = 0.001  # скорость обучения нейронной сети
# training_steps = 3000  # максимальное число эпох
batch_size = 256  # пересчитывать веса сети мы будем не на всей выборке, а на ее случайном подможестве из batch_size элементов
# display_step = 100  # каждые 100 итераций мы будем показывать текущее значение функции потерь и точности

n_hidden_1 = 128  # количество нейронов 1-го слоя
n_hidden_2 = 256  # количество нейронов 2-го слоя

BUFFER_SIZE = 5000  # This dataset fills a buffer with buffer_size elements, then randomly samples elements from this buffer, replacing the selected elements with new elements.

# %%
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()
x_train.dtype, x_train[0].shape
# Out:
# (dtype('uint8'), (28, 28))

# %%
NUM_FEATURES = x_train[0].shape[0] * x_train[0].shape[1]

# %%
x_train, x_test = np.array(x_train, np.float32), np.array(x_test, np.float32)

# each sample (28x28) to 1x784
x_train, x_test = x_train.reshape([-1, NUM_FEATURES]), x_test.reshape([-1, NUM_FEATURES])
print(min(x_train.min(), x_test.min()))
maximum = max(x_train.max(), x_test.max()) # np.max([x_train.max(), x_test.max()]) 
maximum
# Out:
# 0.0
# 255.0

# %%
# Normalize (min = 0)
x_train, x_test = x_train / maximum, x_test / maximum

# %%
# Перемешаем тренировочные данные (split to batches & ...)
# train_data = tf.data.Dataset.from_tensor_slices((x_train, y_train))
# train_data = train_data.repeat().shuffle(BUFFER_SIZE).batch(batch_size).prefetch(1)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((60000, 784), (10000, 784), (60000,), (10000,))

# %%
max(y_train.max(), y_test.max()), min(y_train.min(), y_test.min())
# Out:
# (9, 0)

# %%
type(y_train)
# Out:
# numpy.ndarray

# %%
NUM_CLASSES = len(set(np.concatenate((y_train, y_test), axis=0)))
NUM_CLASSES
# Out:
# 10

# %%
# y_true = tf.one_hot(y_train, depth=NUM_CLASSES)
# y_true.shape
# Out:
# TensorShape([60000, 10])

# %% [markdown]
# ###### __Model__

# %% [markdown]
# - https://www.tensorflow.org/api_docs/python/tf/keras/optimizers
# - https://www.tensorflow.org/api_docs/python/tf/keras/losses/CategoricalCrossentropy

# %%
# number of hidden layers
n_layers = [el for el in range(1, 4)]  # 1, 2, 3
n_of_neurons = [[2**el for el in range(1, 9)] for _ in n_layers]
activations = ['mish', 'relu', 'sigmoid', 'softmax']
n_epoch = 10  # max limit
batch_size = [2**el for el in range(7, 10)]
optimizators = [optimizers.legacy.SGD, optimizers.legacy.RMSprop, optimizers.legacy.Adam]
learning_rate = [10**el for el in range(-3, 0)]

# %%
model = Sequential()
model.add(Dense(n_hidden_1, activation='sigmoid', input_shape=(NUM_FEATURES,)))
model.add(Dense(n_hidden_2, activation='sigmoid'))
model.add(Dense(10, activation='softmax'))

model.compile(
              optimizer=optimizers.SGD(learning_rate=0.001), # legacy
              loss=losses.CategoricalCrossentropy(),  # 'categorical_crossentropy' losses.binary_crossentropy,
              metrics=['accuracy']  # metrics.Accuracy()
              )

# %% [markdown]
# ###### __Training__

# %%
y_true = tf.one_hot(y_train, depth=NUM_CLASSES).numpy()
y_truev = tf.one_hot(y_test, depth=NUM_CLASSES).numpy()
y_true.shape, y_truev.shape
# Out:
# ((60000, 10), (10000, 10))

# %%
# x_val = x_train[:10000]
# partial_x_train = x_train[10000:]

# y_val = y_train[:10000]
# partial_y_train = y_train[10000:]

history = model.fit(
                    x_train,
                    y_true,
                    epochs=100,
                    batch_size=256,
                    validation_data=(x_test, y_truev)
                    )
# Out:
# Epoch 1/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.3362 - accuracy: 0.0717 - val_loss: 2.3041 - val_accuracy: 0.0636
# Epoch 2/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2985 - accuracy: 0.1115 - val_loss: 2.2956 - val_accuracy: 0.1400
# Epoch 3/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2933 - accuracy: 0.1815 - val_loss: 2.2918 - val_accuracy: 0.1647
# Epoch 4/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2896 - accuracy: 0.2097 - val_loss: 2.2881 - val_accuracy: 0.2318
# Epoch 5/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2859 - accuracy: 0.2529 - val_loss: 2.2844 - val_accuracy: 0.2849
# Epoch 6/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2822 - accuracy: 0.2973 - val_loss: 2.2807 - val_accuracy: 0.3122
# Epoch 7/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2785 - accuracy: 0.3226 - val_loss: 2.2770 - val_accuracy: 0.3497
# Epoch 8/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2747 - accuracy: 0.3523 - val_loss: 2.2732 - val_accuracy: 0.3858
# Epoch 9/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2709 - accuracy: 0.3986 - val_loss: 2.2695 - val_accuracy: 0.4155
# Epoch 10/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2671 - accuracy: 0.4305 - val_loss: 2.2657 - val_accuracy: 0.4167
# Epoch 11/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2632 - accuracy: 0.4153 - val_loss: 2.2618 - val_accuracy: 0.4584
# Epoch 12/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2594 - accuracy: 0.4724 - val_loss: 2.2579 - val_accuracy: 0.4672
# Epoch 13/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2554 - accuracy: 0.4738 - val_loss: 2.2540 - val_accuracy: 0.4907
# Epoch 14/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2514 - accuracy: 0.4969 - val_loss: 2.2499 - val_accuracy: 0.5017
# Epoch 15/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2473 - accuracy: 0.5025 - val_loss: 2.2459 - val_accuracy: 0.5169
# Epoch 16/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2432 - accuracy: 0.5234 - val_loss: 2.2417 - val_accuracy: 0.5167
# Epoch 17/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2390 - accuracy: 0.5163 - val_loss: 2.2375 - val_accuracy: 0.5379
# Epoch 18/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2347 - accuracy: 0.5365 - val_loss: 2.2332 - val_accuracy: 0.5327
# Epoch 19/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2303 - accuracy: 0.5495 - val_loss: 2.2288 - val_accuracy: 0.5385
# Epoch 20/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2258 - accuracy: 0.5530 - val_loss: 2.2243 - val_accuracy: 0.5406
# Epoch 21/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2213 - accuracy: 0.5500 - val_loss: 2.2196 - val_accuracy: 0.5552
# Epoch 22/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2166 - accuracy: 0.5627 - val_loss: 2.2149 - val_accuracy: 0.5529
# Epoch 23/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2118 - accuracy: 0.5650 - val_loss: 2.2101 - val_accuracy: 0.5603
# Epoch 24/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2068 - accuracy: 0.5753 - val_loss: 2.2051 - val_accuracy: 0.5583
# Epoch 25/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.2018 - accuracy: 0.5776 - val_loss: 2.2000 - val_accuracy: 0.5542
# Epoch 26/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1966 - accuracy: 0.5650 - val_loss: 2.1948 - val_accuracy: 0.5840
# Epoch 27/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1912 - accuracy: 0.5868 - val_loss: 2.1894 - val_accuracy: 0.5834
# Epoch 28/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1857 - accuracy: 0.5766 - val_loss: 2.1838 - val_accuracy: 0.5943
# Epoch 29/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1801 - accuracy: 0.5966 - val_loss: 2.1781 - val_accuracy: 0.5764
# Epoch 30/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1742 - accuracy: 0.5891 - val_loss: 2.1723 - val_accuracy: 0.5856
# Epoch 31/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1683 - accuracy: 0.5980 - val_loss: 2.1662 - val_accuracy: 0.5729
# Epoch 32/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1621 - accuracy: 0.5829 - val_loss: 2.1600 - val_accuracy: 0.6059
# Epoch 33/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1557 - accuracy: 0.6062 - val_loss: 2.1535 - val_accuracy: 0.5982
# Epoch 34/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1492 - accuracy: 0.6022 - val_loss: 2.1469 - val_accuracy: 0.6013
# Epoch 35/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1424 - accuracy: 0.6015 - val_loss: 2.1400 - val_accuracy: 0.6102
# Epoch 36/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1354 - accuracy: 0.6098 - val_loss: 2.1329 - val_accuracy: 0.6047
# Epoch 37/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1281 - accuracy: 0.6036 - val_loss: 2.1256 - val_accuracy: 0.6091
# Epoch 38/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1207 - accuracy: 0.6059 - val_loss: 2.1181 - val_accuracy: 0.6187
# Epoch 39/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1130 - accuracy: 0.6140 - val_loss: 2.1103 - val_accuracy: 0.6115
# Epoch 40/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.1051 - accuracy: 0.6008 - val_loss: 2.1023 - val_accuracy: 0.6185
# Epoch 41/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0969 - accuracy: 0.6145 - val_loss: 2.0941 - val_accuracy: 0.6193
# Epoch 42/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0885 - accuracy: 0.6199 - val_loss: 2.0855 - val_accuracy: 0.6131
# Epoch 43/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0797 - accuracy: 0.6109 - val_loss: 2.0767 - val_accuracy: 0.6225
# Epoch 44/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0708 - accuracy: 0.6218 - val_loss: 2.0677 - val_accuracy: 0.6105
# Epoch 45/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0615 - accuracy: 0.6031 - val_loss: 2.0583 - val_accuracy: 0.6219
# Epoch 46/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0520 - accuracy: 0.6221 - val_loss: 2.0487 - val_accuracy: 0.6196
# Epoch 47/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0422 - accuracy: 0.6226 - val_loss: 2.0388 - val_accuracy: 0.6098
# Epoch 48/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0321 - accuracy: 0.6153 - val_loss: 2.0286 - val_accuracy: 0.6203
# Epoch 49/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0218 - accuracy: 0.6206 - val_loss: 2.0182 - val_accuracy: 0.6204
# Epoch 50/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0112 - accuracy: 0.6250 - val_loss: 2.0075 - val_accuracy: 0.6102
# Epoch 51/100
# 235/235 [==============================] - 1s 4ms/step - loss: 2.0003 - accuracy: 0.6144 - val_loss: 1.9965 - val_accuracy: 0.6185
# Epoch 52/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.9891 - accuracy: 0.6211 - val_loss: 1.9853 - val_accuracy: 0.6084
# Epoch 53/100
# 235/235 [==============================] - 1s 5ms/step - loss: 1.9776 - accuracy: 0.6156 - val_loss: 1.9738 - val_accuracy: 0.6100
# Epoch 54/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.9660 - accuracy: 0.6147 - val_loss: 1.9620 - val_accuracy: 0.6179
# Epoch 55/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.9540 - accuracy: 0.6169 - val_loss: 1.9500 - val_accuracy: 0.6167
# Epoch 56/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.9418 - accuracy: 0.6206 - val_loss: 1.9378 - val_accuracy: 0.6112
# Epoch 57/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.9294 - accuracy: 0.6102 - val_loss: 1.9253 - val_accuracy: 0.6159
# Epoch 58/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.9169 - accuracy: 0.6146 - val_loss: 1.9127 - val_accuracy: 0.6099
# Epoch 59/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.9041 - accuracy: 0.6148 - val_loss: 1.8999 - val_accuracy: 0.6045
# Epoch 60/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.8911 - accuracy: 0.6115 - val_loss: 1.8869 - val_accuracy: 0.6039
# Epoch 61/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.8780 - accuracy: 0.6089 - val_loss: 1.8738 - val_accuracy: 0.6054
# Epoch 62/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.8647 - accuracy: 0.6043 - val_loss: 1.8605 - val_accuracy: 0.6126
# Epoch 63/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.8513 - accuracy: 0.6123 - val_loss: 1.8472 - val_accuracy: 0.6036
# Epoch 64/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.8379 - accuracy: 0.6036 - val_loss: 1.8338 - val_accuracy: 0.6071
# Epoch 65/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.8244 - accuracy: 0.6075 - val_loss: 1.8203 - val_accuracy: 0.5983
# Epoch 66/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.8108 - accuracy: 0.6021 - val_loss: 1.8067 - val_accuracy: 0.6031
# Epoch 67/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.7972 - accuracy: 0.6018 - val_loss: 1.7932 - val_accuracy: 0.5979
# Epoch 68/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.7835 - accuracy: 0.6006 - val_loss: 1.7796 - val_accuracy: 0.5991
# Epoch 69/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.7699 - accuracy: 0.5969 - val_loss: 1.7661 - val_accuracy: 0.6035
# Epoch 70/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.7563 - accuracy: 0.6075 - val_loss: 1.7526 - val_accuracy: 0.5894
# Epoch 71/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.7428 - accuracy: 0.5984 - val_loss: 1.7392 - val_accuracy: 0.5895
# Epoch 72/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.7293 - accuracy: 0.5958 - val_loss: 1.7259 - val_accuracy: 0.5938
# Epoch 73/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.7160 - accuracy: 0.5980 - val_loss: 1.7126 - val_accuracy: 0.5941
# Epoch 74/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.7027 - accuracy: 0.5982 - val_loss: 1.6995 - val_accuracy: 0.5913
# Epoch 75/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6896 - accuracy: 0.5968 - val_loss: 1.6865 - val_accuracy: 0.5905
# Epoch 76/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6765 - accuracy: 0.5969 - val_loss: 1.6736 - val_accuracy: 0.5922
# Epoch 77/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6637 - accuracy: 0.5964 - val_loss: 1.6609 - val_accuracy: 0.5930
# Epoch 78/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6509 - accuracy: 0.6016 - val_loss: 1.6483 - val_accuracy: 0.5858
# Epoch 79/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6384 - accuracy: 0.5923 - val_loss: 1.6359 - val_accuracy: 0.5917
# Epoch 80/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6260 - accuracy: 0.5972 - val_loss: 1.6237 - val_accuracy: 0.5922
# Epoch 81/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6137 - accuracy: 0.5966 - val_loss: 1.6116 - val_accuracy: 0.5942
# Epoch 82/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.6017 - accuracy: 0.5987 - val_loss: 1.5997 - val_accuracy: 0.5929
# Epoch 83/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5898 - accuracy: 0.5964 - val_loss: 1.5880 - val_accuracy: 0.5943
# Epoch 84/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5782 - accuracy: 0.5987 - val_loss: 1.5765 - val_accuracy: 0.5910
# Epoch 85/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5667 - accuracy: 0.5969 - val_loss: 1.5652 - val_accuracy: 0.5956
# Epoch 86/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5554 - accuracy: 0.5995 - val_loss: 1.5541 - val_accuracy: 0.5976
# Epoch 87/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5442 - accuracy: 0.6010 - val_loss: 1.5431 - val_accuracy: 0.5989
# Epoch 88/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5333 - accuracy: 0.6022 - val_loss: 1.5324 - val_accuracy: 0.5982
# Epoch 89/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5226 - accuracy: 0.6032 - val_loss: 1.5218 - val_accuracy: 0.5984
# Epoch 90/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5121 - accuracy: 0.6034 - val_loss: 1.5114 - val_accuracy: 0.5990
# Epoch 91/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.5017 - accuracy: 0.6041 - val_loss: 1.5012 - val_accuracy: 0.5997
# Epoch 92/100
# 235/235 [==============================] - 1s 5ms/step - loss: 1.4915 - accuracy: 0.6071 - val_loss: 1.4912 - val_accuracy: 0.5974
# Epoch 93/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.4816 - accuracy: 0.6050 - val_loss: 1.4814 - val_accuracy: 0.6006
# Epoch 94/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.4717 - accuracy: 0.6054 - val_loss: 1.4718 - val_accuracy: 0.6047
# Epoch 95/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.4621 - accuracy: 0.6092 - val_loss: 1.4623 - val_accuracy: 0.6029
# Epoch 96/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.4527 - accuracy: 0.6074 - val_loss: 1.4530 - val_accuracy: 0.6087
# Epoch 97/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.4434 - accuracy: 0.6119 - val_loss: 1.4439 - val_accuracy: 0.6074
# Epoch 98/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.4343 - accuracy: 0.6130 - val_loss: 1.4349 - val_accuracy: 0.6044
# Epoch 99/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.4253 - accuracy: 0.6119 - val_loss: 1.4261 - val_accuracy: 0.6058
# Epoch 100/100
# 235/235 [==============================] - 1s 4ms/step - loss: 1.4166 - accuracy: 0.6135 - val_loss: 1.4175 - val_accuracy: 0.6087

# %% [markdown]
# ###### __Error Analysis__

# %%
print(history.history.keys())
""" 
loss - список, в якому зберігається історія змін помилки на навчальних даних залежно від епохи
val_loss - список, де зберігається історія змін помилки на тестових даних залежно від епохи
accuracy - список, в якому зберігається історія змін точності на навчальних даних залежно від епохи
val_accuracy - список, де зберігається історія змін точності на тестових даних залежно від епохи
"""
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])
# ' \nloss - список, в якому зберігається історія змін помилки на навчальних даних залежно від епохи\nval_loss - список, де зберігається історія змін помилки на тестових даних залежно від епохи\naccuracy - список, в якому зберігається історія змін точності на навчальних даних залежно від епохи\nval_accuracy - список, де зберігається історія змін точності на тестових даних залежно від епохи\n'

# %%
history_dict = history.history
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']

epochs = range(1, len(history_dict['accuracy']) + 1)

plt.figure(figsize=(12, 12))
plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'g', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()


plt.clf()
plt.figure(figsize=(12, 12))
val_acc_values = history_dict['val_accuracy']
plt.plot(epochs, history_dict['accuracy'], 'bo', label='Training acc')
plt.plot(epochs, history_dict['val_accuracy'], 'g', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Acc')
plt.legend()
